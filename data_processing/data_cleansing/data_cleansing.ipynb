# %%
import pandas as pd
def read_csv(file_path):
    return pd.read_csv(file_path)

file_path = '../../data/datasets/rodrigues/flights.csv'

#df means data frame
df = read_csv(file_path)

# %%
rows_to_delete = [278, 279]

def clean_data(df):
    df = df[~df['flight'].isin(rows_to_delete)]
    return df

# Step 2: Clean the data
df = clean_data(df)

# %%
def write_csv(df, output_path):
    df.to_csv(output_path, index=False)

output_path = '../../data/datasets/rodrigues/corrected_flights.csv'
write_csv(df, output_path)

# %%
df.head()
# Out:
#    flight  time  wind_speed  wind_angle  battery_voltage  battery_current  \
# 0       1   0.0         0.1        12.0        24.222174         0.087470
# 1       1   0.2         0.1         3.0        24.227180         0.095421
# 2       1   0.3         0.1       352.0        24.225929         0.095421
# 3       1   0.5         0.1       354.0        24.224678         0.095421
# 4       1   0.6         0.1       359.0        24.210905         0.079518
#
#    position_x  position_y  position_z  orientation_x  ...  angular_z  \
# 0  -79.782396   40.458047  269.332402       0.001772  ...   0.006815
# 1  -79.782396   40.458047  269.332056       0.001768  ...   0.002034
# 2  -79.782396   40.458047  269.333081       0.001768  ...  -0.000874
# 3  -79.782396   40.458047  269.334648       0.001775  ...   0.002443
# 4  -79.782396   40.458047  269.336178       0.001775  ...  -0.006425
#
#    linear_acceleration_x  linear_acceleration_y  linear_acceleration_z  speed  \
# ...

# %%
df.tail()
# Out:
#         flight    time  wind_speed  wind_angle  battery_voltage  \
# 255706     277  134.20         1.7       151.0        24.476339
# 255707     277  134.31         1.7       150.0        24.482599
# 255708     277  134.40         1.9       150.0        24.485104
# 255709     277  134.61         1.9       149.0        24.482599
# 255710     277  134.81         2.1       144.0        24.488859
#
#         battery_current  position_x  position_y  position_z  orientation_x  \
# 255706         0.063614  -79.782777    40.45904  270.108316      -0.006789
# 255707         0.071566  -79.782777    40.45904  270.111224      -0.006774
# 255708         0.095421  -79.782777    40.45904  270.114216      -0.006766
# 255709         0.079518  -79.782777    40.45904  270.119822      -0.006744
# 255710         0.063614  -79.782777    40.45904  270.122567      -0.006750
#
#         ...  angular_z  linear_acceleration_x  linear_acceleration_y  \
# ...
